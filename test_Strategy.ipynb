# %% [markdown]
# # Libraries Import

# %%
import matplotlib.pyplot as plt
plt.style.use("seaborn")
import MetaTrader5 as mt5
import plotly.express as px
from prepare_data import *
from Strategies.Stratey_bb_adx_rsi_ema200_1MIN import Strategy_bb_adx_rsi_ema200_1MIN
from Strategies.Strategy_rsi_stoch_ema50 import Strategy_rsi_stoch_ema50_1H
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.16.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # Import Data

# %%
data = import_csv_data("C:/Users/u/Downloads/US100_15MIN.csv")
data = clean_data(data)

# %% [markdown]
# # Prepare Data

# %%
data = prepare_data(data)
# Out:
# e:\Programmes\python\lib\site-packages\ta\trend.py:769: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# e:\Programmes\python\lib\site-packages\ta\trend.py:774: RuntimeWarning:
#
# invalid value encountered in double_scalars

# %% [markdown]
# # Parameters

# %%
ratio = 2.49
security_sl = 5
security_sl_1 = security_sl
security_sl_2 = security_sl
volume_control = 0
starting_balance = 1000
volume = 1
spread = 1*volume

# %% [markdown]
# # Run the Strategy

# %%
rsi_stoch_strategy = Strategy_rsi_stoch_ema50_1H(data, starting_balance=starting_balance, volume=volume, security_sl=security_sl, ratio=ratio, spread=spread)
result = rsi_stoch_strategy.run()

# %% [markdown]
# ### Plot result

# %%
plot_trades_result(data, result)
# Out:
# <div>                            <div id="ba33cd4b-4828-413a-a6be-982633320b7b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ba33cd4b-4828-413a-a6be-982633320b7b")) {                    Plotly.newPlot(                        "ba33cd4b-4828-413a-a6be-982633320b7b",                        [{"close":[12534.7,12545.8,12536.9,12552.5,12563.2,12589.4,12586.1,12634.4,12644.2,12625.7,12621.3,12611.7,12614.5,12628.1,12625.0,12635.7,12633.1,12625.6,12618.8,12616.0,12611.5,12611.6,12597.3,12604.6,12574.8,12563.1,12551.4,12565.1,12553.4,12492.8,12464.4,12416.0,12393.6,12294.1,12323.6,12313.3,12333.6,12332.4,12333.7,12361.3,12335.7,12294.9,12304.9,12264.1,12273.0,12243.5,12289.1,12302.9,12273.5,12278.5,12293.9,12357.4,12341.5,12338.4,12344.1,12362.2,12359.6,12357.4,12348.7,12346.5,12343.8,12356.8,12359.2,12348.8,12352.1,12349.1,12356.5,12373.0,12380.2,12397.5,12395.3,12395.5,12392.9,12406.6,12397.2,12398.5,12400.2,12411.0,12406.5,12413.0,12433.1,12429.3,12427.1,12430.1,12423.8,12449.9,12441.2,12444.9,12447.1,12429.4,12438.9,12448.6,12431.1,12423.2,12432.7,12424.8,12417.7,12388.3,12386.5,12382.8,12371.5,12387.5,12382.9,12354.1,12355.7,12371.3,12370.1,12398.0,12416.6,12432.3,12431.1,12420.9,12425.1,12411.0,12422.3,12425.5,12440.7,12419.3,12445.1,12459.2,12464.2,12473.3,12444.7,12426.1,12374.0,12386.9,12350.9,12308.2,12319.1,12369.9,12379.3,12367.7,12356.2,12334.5,12333.6,12344.7,12310.8,12288.6,12303.2,12319.1,12314.7,12273.5,12288.0,12337.1,12325.3,12361.9,12270.5,12292.4,12296.4,12296.1,12293.6,12255.9,12215.0,12200.9,12215.9,12191.9,12151.6,12155.6,12166.7,12144.0,12
00:00","2022-10-25T20:00:00+00:00","2022-10-26T14:45:00+00:00","2022-10-26T16:45:00+00:00","2022-10-27T12:15:00+00:00","2022-10-27T20:00:00+00:00","2022-10-27T22:00:00+00:00","2022-10-28T13:30:00+00:00","2022-10-28T15:00:00+00:00","2022-10-28T19:45:00+00:00","2022-10-31T00:15:00+00:00","2022-10-31T08:30:00+00:00","2022-10-31T11:00:00+00:00","2022-10-31T12:00:00+00:00","2022-10-31T13:45:00+00:00","2022-10-31T15:45:00+00:00","2022-11-01T05:30:00+00:00","2022-11-01T08:00:00+00:00","2022-11-01T13:45:00+00:00","2022-11-02T19:15:00+00:00","2022-11-03T13:45:00+00:00","2022-11-03T14:15:00+00:00","2022-11-04T12:30:00+00:00","2022-11-04T13:30:00+00:00","2022-11-10T13:45:00+00:00","2022-11-10T20:00:00+00:00", ...

# %% [markdown]
# ### % win vs % loss

# %%
loss = 0
win = 0
for index, row in result.iterrows():
  if row["profit"] < 0:
    loss = loss + 1
  else :
    win = win + 1

Win_ = (win) / (win + loss) * 100
Loss_ = loss / (win+loss) * 100

# %%
print(f"pourcentage Win {Win_}%")
# Out:
# pourcentage Win 35.754189944134076%

# %%
print(f"pourcentage Loss {Loss_}%")
# Out:
# pourcentage Loss 64.24581005586593%

# %% [markdown]
# # Optimization

# %% [markdown]
# ### Optimization SL

# %%
starting_balance = 1000
volume = 1
spread = 1*volume
ratio = 2.49

max_profit = {"security_sl": 0, "pnl": 0}

for i in range(300):
  rsi_stoch_strategy = Strategy_rsi_stoch_ema50_1H(data, starting_balance=starting_balance, volume=volume, security_sl=i, ratio=ratio, spread=spread)
  result = rsi_stoch_strategy.run()
  current_max_profit = result["pnl"].iat[-2]
  if current_max_profit > max_profit["pnl"]:
    max_profit["security_sl"] = i
    max_profit["pnl"] = current_max_profit

max_profit
# Out:
# {'security_sl': 5, 'pnl': 5190.385438211901}

# %% [markdown]
# # Optimization +++

# %% [markdown]
# #### Optimization SL ++

# %%
starting_balance = 1000
volume = 1
spread = 1*volume

max_profit = {"security_sl": 0, "ratio": 0, "pnl": 0}

for i in range(100, 300):
  ratio = i/100
  for j in range(100):
    rsi_stoch_strategy = Strategy_rsi_stoch_ema50_1H(data, starting_balance=starting_balance, volume=volume, ratio=ratio, spread=spread, security_sl=j)
    result = rsi_stoch_strategy.run()
    current_max_pnl = result["pnl"].iat[-2]
    if current_max_pnl > max_profit["pnl"]:
      max_profit["security_sl"] = j
      max_profit["ratio"] = ratio
      max_profit["pnl"] = current_max_pnl

max_profit
    

max_profit
# Out:
# {'security_sl': 249, 'ratio': 0, 'pnl': 5190.385438211901}

# %% [markdown]
# # Excel File

# %%
result.drop(result.tail(1).index,inplace=True)
write_excel_file(result)

# %% [markdown]
# # Saved Results

# %% [markdown]
# ### US100-1H
# #### Double sl : 1) 47.5 < atr < 62.5, ratio=1.5
# {'security_sl_1': 15, 'security_sl_2': 22, 'pnl': 4429}
#
# ### US100-15MIN
# #### Simple sl : sl = 5, ratio = 2.49
# {'security_sl': 5, 'ratio': 2.49, 'pnl': 5225}
