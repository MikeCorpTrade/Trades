# %% [markdown]
# # Libraries Import

# %%
import matplotlib.pyplot as plt
plt.style.use("seaborn")
# import MetaTrader5 as mt5
import plotly.express as px
from prepare_data import *
from Strategies.Stratey_bb_adx_rsi_ema200_1MIN import Strategy_bb_adx_rsi_ema200_1MIN
from Strategies.Strategy_rsi_stoch_ema50 import Strategy_rsi_stoch_ema50
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.16.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # Import Data

# %%
data = import_csv_data("./csv_files/15MIN/FRA40_15MIN.csv")
data = clean_data(data)

# %% [markdown]
# # Prepare Data

# %%
data = prepare_data(data)
# Out:
# e:\Programmes\python\lib\site-packages\ta\trend.py:769: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# e:\Programmes\python\lib\site-packages\ta\trend.py:774: RuntimeWarning:
#
# invalid value encountered in double_scalars

# %% [markdown]
# # Parameters

# %%
ratio = 1.5
security_sl = 85
security_sl_1 = security_sl
security_sl_2 = security_sl
volume_control = 0
starting_balance = 1000
volume = 1
spread = 1*volume

# %% [markdown]
# # Run the Strategy

# %%
rsi_stoch_strategy = Strategy_rsi_stoch_ema50(data, starting_balance=starting_balance, volume=volume, security_sl=security_sl, ratio=ratio, spread=spread)
result = rsi_stoch_strategy.run()

# %% [markdown]
# ### Plot result

# %%
plot_trades_result(data, result)
# Out:
# <div>                            <div id="6f7cc1b0-832a-4d3c-ad66-362d11c848f5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6f7cc1b0-832a-4d3c-ad66-362d11c848f5")) {                    Plotly.newPlot(                        "6f7cc1b0-832a-4d3c-ad66-362d11c848f5",                        [{"close":[6122.4,6144.6,6152.9,6136.2,6120.4,6101.8,6102.6,6109.4,6088.4,6090.8,6075.8,6076.2,6080.6,6085.8,6084.6,6073.6,6077.8,6062.8,6061.4,6054.4,6063.4,6059.8,6059.4,6053.2,6038.8,6035.2,6037.2,6034.4,6049.4,6060.8,6046.8,6064.6,6054.6,6052.1,6043.6,6032.1,6042.6,6046.6,6040.6,6038.8,6030.4,6029.4,6030.4,6029.6,6031.6,6028.1,6034.1,6031.6,6032.4,6030.4,6076.8,6087.6,6096.6,6094.1,6130.4,6090.4,6081.9,6097.2,6111.4,6114.2,6114.4,6124.6,6135.8,6132.6,6110.2,6114.4,6112.2,6116.6,6117.2,6129.2,6130.6,6130.4,6126.8,6130.2,6128.8,6108.6,6117.8,6113.2,6110.6,6115.6,6135.6,6132.2,6123.2,6109.8,6107.6,6105.8,6108.4,6087.4,6066.6,6060.8,6063.1,6065.6,6069.9,6064.4,6041.6,6053.4,6046.6,6047.1,6037.1,6037.8,6028.6,6032.1,6031.1,6037.4,6032.4,6020.9,6042.8,6039.4,6025.4,6020.6,6058.2,6056.6,6053.6,6028.6,6039.6,6041.6,6043.2,6044.2,6043.2,6040.6,6030.6,6003.6,6010.6,6001.4,6007.2,6012.4,6003.4,6009.4,6014.8,6028.6,6047.2,6034.9,6027.6,6030.8,6042.2,6044.6,6017.9,6041.2,6045.6,6032.6,6041.4,6029.6,6029.6,6025.2,6031.6,6035.6,6016.6,6010.4,6023.1,6024.1,6019.4,6022.1,6029.4,6036.6,6042.4,6041.4,6020.6,6025.4,6029.8,6038.1,6021.8,6016.4,5947.6,5931.6,5911.8,5924.4,5903.4,5895.4,5914.4,5905.6,5918.6,5896.8,5926.2,5905.6,5884.2,5872.4,5886.8,5908.4,5890.4,5876.8,5869.6,5872.6,5867.6,5865.9,5859.2,5868.6,5873.6,5881.8,5894.2,5869.2,5877.8,5883.2,5872.6,5866.6,5880.2,5871.4,5884.4,5900.6,5908.4,5909.4,5935.6,5940.4,5931.4,5953.8,5950.9,5948.9,5927.1,5937.6,5934
%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2022-06-27T15:45:00+02:00","2022-06-28T21:45:00+02:00","2022-06-30T12:30:00+02:00","2022-07-05T14:00:00+02:00","2022-07-06T09:30:00+02:00","2022-07-08T12:15:00+02:00","2022-07-18T08:00:00+02:00","2022-07-25T13:30:00+02:00","2022-07-29T08:00:00+02:00","2022-08-22T21:30:00+02:00","2022-08-29T08:00:00+02:00","2022-08-31T11:00:00+02:00","2022-09-01T10:45:00+02:00","2022-09-02T16:00:00+02:00","2022-09-08T08:00:00+02:00","2022-09-12T10:15:00+02:00","2022-09-16T09:30:00+02:00","2022-09-20T19:45:00+02:00","2022-09-23T15:45:00+02:00","2022-10-04T09:00:00+02:00","2022-10-07T14:30:00+02:00","2022-10-13T14:30:00+02:00","2022-10-18T08:00:00+02:00","2022-10-21T14:00:00+02:00","2022-10-25T16:15:00+02:00","2022-11-01T09:30:00+01:00","2022-11-02T16:00:00+01:00","2022-11-04T14:00:00+01:00","2022-11-11T08:00:00+01:00","2022-11-30T10:15:00+01:00",null],"xaxis":"x","y":[905.8000000000002,809.6000000000004,973.8999999999996,868.3999999999996,768.1000000000004,936.3000000000011,838.3000000000011,992.1000000000004,1142.000000000001,1029.4000000000005,1195.1999999999998,1098.3000000000002,1248.5,1149.6999999999998,1038.6999999999998,1192.5,1344.2000000000007,1495.000000000001,1713.000000000001,1564.8000000000002,1459.0,1360.0,1521.0,1413.0,1571.9000000000005,1706.1999999999998,1608.0,1457.3000000000002,1645.75,1791.75,null],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c ...

# %% [markdown]
# ### % win vs % loss

# %%
loss = 0
win = 0
for index, row in result.iterrows():
  if row["profit"] < 0:
    loss = loss + 1
  else :
    win = win + 1

Win_ = (win) / (win + loss) * 100
Loss_ = loss / (win+loss) * 100

# %%
print(f"pourcentage Win {Win_}%")

# %%
print(f"pourcentage Loss {Loss_}%")

# %% [markdown]
# # Optimization

# %% [markdown]
# ### Optimization SL

# %%
starting_balance = 1000
volume = 1
spread = 1*volume
ratio = 1.5

max_profit = {"security_sl": 0, "pnl": 0}

for i in range(300):
  rsi_stoch_strategy = Strategy_rsi_stoch_ema50(data, starting_balance=starting_balance, volume=volume, security_sl=i, ratio=ratio, spread=spread)
  result = rsi_stoch_strategy.run()
  current_max_profit = result["pnl"].iat[-1]
  if current_max_profit > max_profit["pnl"]:
    max_profit["security_sl"] = i
    max_profit["pnl"] = current_max_profit

max_profit
# Out:
# {'security_sl': 82, 'pnl': 1934.1500000000024}

# %% [markdown]
# # Optimization +++

# %% [markdown]
# #### Optimization SL ++

# %%
starting_balance = 1000
volume = 1
spread = 1*volume

max_profit = {"security_sl": 0, "ratio": 0, "pnl": 0}

for i in range(100, 300):
  ratio = i/100
  print(f"progress : {ratio}")
  for j in range(100):
    rsi_stoch_strategy = Strategy_rsi_stoch_ema50(data, starting_balance=starting_balance, volume=volume, ratio=ratio, spread=spread, security_sl=j)
    result = rsi_stoch_strategy.run()
    current_max_pnl = result["pnl"].iat[-1]
    if current_max_pnl > max_profit["pnl"]:
      max_profit["security_sl"] = j
      max_profit["ratio"] = ratio
      max_profit["pnl"] = current_max_pnl

max_profit
    

max_profit
# Out:
# progress : 1.0
# progress : 1.01
# progress : 1.02
# progress : 1.03
# progress : 1.04
# progress : 1.05
# progress : 1.06
# progress : 1.07
# progress : 1.08
# progress : 1.09
# progress : 1.1
# progress : 1.11
# progress : 1.12
# progress : 1.13
# progress : 1.14
# progress : 1.15
# progress : 1.16
# progress : 1.17
# progress : 1.18
# progress : 1.19
# progress : 1.2
# progress : 1.21
# progress : 1.22
# progress : 1.23
# progress : 1.24
# progress : 1.25
# progress : 1.26
# progress : 1.27
# progress : 1.28
# progress : 1.29
# progress : 1.3
# progress : 1.31
# progress : 1.32
# progress : 1.33
# progress : 1.34
# progress : 1.35
# progress : 1.36
# progress : 1.37
# progress : 1.38
# progress : 1.39
# progress : 1.4
# progress : 1.41
# progress : 1.42
# progress : 1.43
# progress : 1.44
# progress : 1.45
# progress : 1.46
# progress : 1.47
# progress : 1.48
# progress : 1.49
# progress : 1.5
# progress : 1.51
# progress : 1.52
# progress : 1.53
# progress : 1.54
# progress : 1.55
# progress : 1.56
# progress : 1.57
# progress : 1.58
# progress : 1.59
# progress : 1.6
# progress : 1.61
# progress : 1.62
# progress : 1.63
# progress : 1.64
# progress : 1.65
# progress : 1.66
# progress : 1.67
# progress : 1.68
# progress : 1.69
# progress : 1.7
# progress : 1.71
# progress : 1.72
# progress : 1.73
# progress : 1.74
# progress : 1.75
# progress : 1.76
# progress : 1.77
# progress : 1.78
# progress : 1.79
# progress : 1.8
# progress : 1.81
# progress : 1.82
# progress : 1.83
# progress : 1.84
# progress : 1.85
# progress : 1.86
# progress : 1.87
# progress : 1.88
# progress : 1.89
# progress : 1.9
# progress : 1.91
# progress : 1.92
# progress : 1.93
# progress : 1.94
# progress : 1.95
# progress : 1.96
# progress : 1.97
# progress : 1.98
# progress : 1.99
# progress : 2.0
# progress : 2.01
# progress : 2.02
# progress : 2.03
# progress : 2.04
# progress : 2.05
# progress : 2.06
# progress : 2.07
# progress : 2.08
# progress : 2.09
# progress : 2.1
# progress : 2.11
# progress : 2.12
# progress : 2.13
# progress : 2.14
# progress : 2.15
# progress : 2.16
# progress : 2.17
# progress : 2.18
# progress : 2.19
# progress : 2.2
# progress : 2.21
# progress : 2.22
# progress : 2.23
# progress : 2.24
# progress : 2.25
# progress : 2.26
# progress : 2.27
# progress : 2.28
# progress : 2.29
# progress : 2.3
# progress : 2.31
# progress : 2.32
# progress : 2.33
# progress : 2.34
# progress : 2.35
# progress : 2.36
# progress : 2.37
# progress : 2.38
# progress : 2.39
# progress : 2.4
# progress : 2.41
# progress : 2.42
# progress : 2.43
# progress : 2.44
# progress : 2.45
# progress : 2.46
# progress : 2.47
# progress : 2.48
# progress : 2.49
# progress : 2.5
# progress : 2.51
# progress : 2.52
# progress : 2.53
# progress : 2.54
# progress : 2.55
# progress : 2.56
# progress : 2.57
# progress : 2.58
# progress : 2.59
# progress : 2.6

# %% [markdown]
# # Excel File

# %%
result.drop(result.tail(1).index,inplace=True)
write_excel_file(result)

# %% [markdown]
# # Saved Results

# %% [markdown]
# ### US100-1H
# #### Double sl : 1) 47.5 < atr < 62.5, ratio=1.5
# {'security_sl_1': 15, 'security_sl_2': 22, 'pnl': 4429}
#
# ### FRA40-15MIN
# #### Simple sl : sl = 71, ratio = 1.5

# %% [markdown]
# # Optimization Max Drawdown

# %%
starting_balance = 1000
volume = 1
spread = 1*volume
ratio = 1.5

max_profit = {"security_sl": 0, "pnl": 0, "mdd": -1000}

for i in range(300):
  rsi_stoch_strategy = Strategy_rsi_stoch_ema50(data, starting_balance=starting_balance, volume=volume, security_sl=i, ratio=ratio, spread=spread)
  result = rsi_stoch_strategy.run()
  current_max_dd = max_drawdown(result["pnl"])
  current_max_profit = result["pnl"].iat[-1]
  if current_max_dd > max_profit["mdd"]:
    max_profit["security_sl"] = i
    max_profit["pnl"] = current_max_profit
    max_profit['mdd'] = current_max_dd

max_profit
